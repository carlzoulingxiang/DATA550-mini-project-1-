# %%
library(tidyverse)
library(GGally)
library(caret)
# Out:
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %% [markdown]
# # describe the data
# Individual medical costs billed by health insurance based various features, like age, sex, bmi, number of children, smoke status, and regions.

# %% [markdown]
# # load the data

# %%
df <- read.csv("Medical_Cost.csv")
head(df)
# Out:
#   age sex    bmi    children smoker region    charges
# 1 19  female 27.900 0        yes    southwest 16884.924
# 2 18  male   33.770 1        no     southeast  1725.552
# 3 28  male   33.000 3        no     southeast  4449.462
# 4 33  male   22.705 0        no     northwest 21984.471
# 5 32  male   28.880 0        no     northwest  3866.855
# 6 31  female 25.740 0        no     southeast  3756.622

# %% [markdown]
# # Explore your dataset

# %%
# summary of the dataset
summary(df)
# Out:
#       age            sex                 bmi           children
#  Min.   :18.00   Length:1338        Min.   :15.96   Min.   :0.000
#  1st Qu.:27.00   Class :character   1st Qu.:26.30   1st Qu.:0.000
#  Median :39.00   Mode  :character   Median :30.40   Median :1.000
#  Mean   :39.21                      Mean   :30.66   Mean   :1.095
#  3rd Qu.:51.00                      3rd Qu.:34.69   3rd Qu.:2.000
#  Max.   :64.00                      Max.   :53.13   Max.   :5.000
#     smoker             region             charges
#  Length:1338        Length:1338        Min.   : 1122
#  Class :character   Class :character   1st Qu.: 4740
#  Mode  :character   Mode  :character   Median : 9382
#                                        Mean   :13270
#                                        3rd Qu.:16640
#                                        Max.   :63770

# %%
# check missing values
sum(is.na(df))
# Out:
# [1] 0

# %% [markdown]
# # Initial thoughts
# 1. In this dataset, there's no missing values
# 2. There seems to be some outliers in the column, charges.

# %% [markdown]
# # Wrangling
# As the dataset is clean, we cannot do much about wrangling. However, if we are going to make prediction in the future, we can do one-hot encoding on categorical variables (such as sex, region, and smoker) and removing missing values.

# %% [markdown]
# # Research Questions
# ### are any relevant corralection between the ratio of multiple quantitative variables; such as age/bmi vs charges/children?

# %%
df$age_bmi_ratio = df$age/df$bmi 
df$charges_children_ratio = df$charges/df$children

# %%
ggplot(df, aes(x=age_bmi_ratio, y=charges_children_ratio)) + geom_point()+ 
geom_smooth(method=lm, se=FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “Removed 574 rows containing non-finite values (stat_smooth).”
# plot without title

# %% [markdown]
# We observed a weak positive correlation between age/bmi and charges/children

# %% [markdown]
# ### which are the top 10 states with the highest charges(based on this sample data)?

# %%
df$charges = sort(df$charges, decreasing = TRUE, na.last = TRUE)

# %%
head(df,20)
# Out:
#    age sex    bmi    children smoker region    charges  age_bmi_ratio
# 1  19  female 27.900 0        yes    southwest 63770.43 0.6810036
# 2  18  male   33.770 1        no     southeast 62592.87 0.5330175
# 3  28  male   33.000 3        no     southeast 60021.40 0.8484848
# 4  33  male   22.705 0        no     northwest 58571.07 1.4534244
# 5  32  male   28.880 0        no     northwest 55135.40 1.1080332
# 6  31  female 25.740 0        no     southeast 52590.83 1.2043512
# 7  46  female 33.440 1        no     southeast 51194.56 1.3755981
# 8  37  female 27.740 3        no     northwest 49577.66 1.3338140
# 9  37  male   29.830 2        no     northeast 48970.25 1.2403621
# 10 60  female 25.840 0        no     northwest 48885.14 2.3219814
# 11 25  male   26.220 0        no     northeast 48824.45 0.9534706
# 12 62  female 26.290 0        yes    southeast 48675.52 2.3583111
# 13 23  male   34.400 0        no     southwest 48673.56 0.6686047
# 14 56  female 39.820 0        no     southeast 48549.18 1.4063285
# 15 27  male   42.130 0        yes    southeast 48517.56 0.6408735
# 16 19  male   24.600 1        no     southwest 48173.36 0.7723577
# 17 52  female 30.780 1        no     northeast 47928.03 1.6894087
# 18 23  male   23.845 0        no     northeast 47896.79 0.9645628
# 19 56  male   40.300 0        no     southwest 47496.49 1.3895782
# 20 30  male   35.300 0        yes    southwest 47462.89 0.8498584
#    charges_children_ratio
# 1        Inf
# 2   1725.552
# 3   1483.154
# 4        Inf
# 5        Inf
# 6        Inf
# 7   8240.590
# 8   2427.169
# 9   3203.205
# 10       Inf
# 11       Inf
# 12       Inf
# 13       Inf
# 14       Inf
# 15       Inf
# 16  1837.237
# 17 10797.336
# 18       Inf
# 19       Inf
# 20       Inf

# %% [markdown]
# The top 10 states with the highest charges are shown in the region column in the data frame above

# %% [markdown]
# ### Can we plot the regions with oldest population and higest charges?

# %%
new_df <- df %>% group_by(region, age) %>% summarise(Mean_charges = mean(charges, na.rm=TRUE))
# Out:
# `summarise()` has grouped output by 'region'. You can override using the `.groups` argument.

# %%
options(repr.plot.width=20, repr.plot.height=10, repr.plot.res = 300)
ggplot(new_df) + aes(x=age, 
                 y=Mean_charges, 
                 color=region)+ 
            geom_line()+
            theme(text = element_text(size = 20))
# Out:
# plot without title

# %% [markdown]
# # Data analysis & visualizations

# %%
temp = df %>% count(region, smoker)
temp
# Out:
#   region    smoker n
# 1 northeast no     257
# 2 northeast yes     67
# 3 northwest no     267
# 4 northwest yes     58
# 5 southeast no     273
# 6 southeast yes     91
# 7 southwest no     267
# 8 southwest yes     58

# %%
holder = temp %>% 
  group_by(region) %>%
  summarise(value=n[smoker == "yes"] / n[smoker == "no"])

# %%
temp2 = df%>%group_by(region)%>%summarise(mean=mean(charges))
temp2
# Out:
#   region    mean
# 1 northeast 13060.23
# 2 northwest 13388.09
# 3 southeast 13483.23
# 4 southwest 13123.95

# %%
holder$mean_charges = temp2$mean
holder
# Out:
#   region    value     mean_charges
# 1 northeast 0.2607004 13060.23
# 2 northwest 0.2172285 13388.09
# 3 southeast 0.3333333 13483.23
# 4 southwest 0.2172285 13123.95

# %%
options(repr.plot.width=5, repr.plot.height=3, repr.plot.res = 300)
ggplot(holder, aes(y=mean_charges,x=region)) + 
    geom_bar(position="dodge", stat="identity")+geom_col()+
            theme(text = element_text(size = 10))
# Out:
# plot without title

# %%
ggplot(holder, aes(x=value,y=region)) + 
    geom_bar(position="dodge", stat="identity")+geom_col()+
            theme(text = element_text(size = 10))
# Out:
# plot without title

# %% [markdown]
# Assumption: We performed the above visualization to check whether higher smoker/non smoker ratio leads to higher medical expenses across regions
# By plotting the above two plots, we found that south east region has higher average medical cost followed by smoker to non smoker ratio but this doesn't seems to be true for other regions
